# %% [markdown]
# ## [Data Source](https://ilexir.co.uk/datasets/index.html)

# %%
#Download corpus
# !wget https://s3-eu-west-1.amazonaws.com/ilexir-website-media/Readability_dataset.tar.gz

#Unzip the folder and #Delete the folder
# !tar zxvf Readability_dataset.tar.gz && rm -r Readability_dataset.tar.gz

#Create corpus documents
# !cd Readability_dataset/KET && cat *.txt > A2.txt
# !cd Readability_dataset/PET && cat *.txt > B1.txt
# !cd Readability_dataset/FCE && cat *.txt > B2.txt
# !cd Readability_dataset/CAE && cat *.txt > C1.txt
# !cd Readability_dataset/CPE && cat *.txt > C2.txt

#Create the corpus folder, move relevant files, and delete Readability folder
# !mkdir corpus
# !mv Readability_dataset/KET/A2.txt corpus/
# !mv Readability_dataset/PET/B1.txt corpus/
# !mv Readability_dataset/FCE/B2.txt corpus/
# !mv Readability_dataset/CAE/C1.txt corpus/
# !mv Readability_dataset/CPE/C2.txt corpus/
# !rm -r Readability_dataset
# Out:
# --2020-02-14 18:23:28--  https://s3-eu-west-1.amazonaws.com/ilexir-website-media/Readability_dataset.tar.gz
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.104.226
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.104.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 404459 (395K) [application/x-gzip]
# Saving to: ‘Readability_dataset.tar.gz’
#
# Readability_dataset 100%[===================>] 394.98K  2.35MB/s    in 0.2s
#
# 2020-02-14 18:23:28 (2.35 MB/s) - ‘Readability_dataset.tar.gz’ saved [404459/404459]
#
# Readability_dataset/
# Readability_dataset/KET/
# Readability_dataset/KET/8.txt
# Readability_dataset/KET/9.txt
# Readability_dataset/KET/1.txt
# Readability_dataset/KET/10.txt
# Readability_dataset/KET/11.txt
# Readability_dataset/KET/12.txt
# Readability_dataset/KET/13.txt
# Readability_dataset/KET/14.txt
# Readability_dataset/KET/15.txt
# Readability_dataset/KET/16.txt
# ...

# %%
#Import packages
import pandas as pd
import numpy as np 
#!pip install -U spacy-lookups-data
#!python -m spacy download en_core_web_sm
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
path = 'corpus/A2.txt'
a1 = open(path, 'r')
